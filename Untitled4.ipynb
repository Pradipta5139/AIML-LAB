# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradipta5139/AIML-LAB/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 2: The Water Jug Problem (Solved using BFS)
# Problem Statement:
# You are given two jugs: Jug A with a capacity of 4 litres, and Jug B with a capacity of 3 litres. Neither jug has any markings on it. Using only the following operations — (i) fill a jug completely, (ii) empty a jug completely, (iii) pour water from one jug into the other until either the first jug is empty or the second jug is full — determine the minimum sequence of steps needed to measure out exactly 2 litres of water in any one jug.

# %%
from collections import deque

def solve_water_jug(cap_a=4, cap_b=3, target=2):
    # Initial state: both jugs are empty
    initial_state = (0, 0)

    # Queue for BFS stores: (state, path_taken)
    queue = deque([(initial_state, [])])

    # Set to keep track of visited states
    visited = {initial_state}

    while queue:
        (a, b), path = queue.popleft()

        # Check if the target is reached
        if a == target or b == target:
            return path + [(a, b)]

        # Generate all possible next steps
        possible_steps = [
            ((cap_a, b), "Fill Jug A"),                  # Fill A
            ((a, cap_b), "Fill Jug B"),                  # Fill B
            ((0, b), "Empty Jug A"),                     # Empty A
            ((a, 0), "Empty Jug B"),                     # Empty B
            # Pour A into B
            ((a - min(a, cap_b - b), b + min(a, cap_b - b)), "Pour Jug A -> Jug B"),
            # Pour B into A
            ((a + min(b, cap_a - a), b - min(b, cap_a - a)), "Pour Jug B -> Jug A")
        ]

        for next_state, action in possible_steps:
            if next_state not in visited:
                visited.add(next_state)
                queue.append((next_state, path + [(a, b, action)]))

    return None

# Solve the problem
steps = solve_water_jug()

if steps:
    print("Minimum sequence of steps to measure exactly 2 litres:")
    for i, step in enumerate(steps):
        if len(step) == 3:
            a, b, action = step
            print(f"Step {i}: {action:22} -> Jug A: {a}L, Jug B: {b}L")
        else:
            a, b = step
            print(f"Goal State reached!      -> Jug A: {a}L, Jug B: {b}L")
else:
    print("No solution found.")
# Out:
# Minimum sequence of steps to measure exactly 2 litres:
# Step 0: Fill Jug B             -> Jug A: 0L, Jug B: 0L
# Step 1: Pour Jug B -> Jug A    -> Jug A: 0L, Jug B: 3L
# Step 2: Fill Jug B             -> Jug A: 3L, Jug B: 0L
# Step 3: Pour Jug B -> Jug A    -> Jug A: 3L, Jug B: 3L
# Goal State reached!      -> Jug A: 4L, Jug B: 2L
